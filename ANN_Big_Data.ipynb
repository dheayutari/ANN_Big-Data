# %% [markdown]
# <a href="https://colab.research.google.com/github/dheayutari/ANN_Big-Data/blob/main/ANN_Big_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Import Library**

# %%
# Mengimpor library NumPy
import numpy as np

# Mengimpor library pandas
import pandas as pd

# Mengimpor modul pyplot untuk visualisasi data
import matplotlib.pyplot as plt

# Mengimpor library seaborn
import seaborn as sns

# Mengimpor fungsi train_test_split dari modul model_selection untuk membagi data menjadi set pelatihan dan pengujian
from sklearn.model_selection import train_test_split

# Mengimpor kelas MinMaxScaler dari modul preprocessing untuk menskalaan fitur
from sklearn.preprocessing import MinMaxScaler

# Mengimpor kelas Sequential dari modul models untuk membuat model ANN
from tensorflow.keras.models import Sequential

# Mengimpor kelas Dense dari modul layers untuk menambahkan layer-layer ke dalam model ANN
from tensorflow.keras.layers import Dense

# Mengimpor kelas LinearRegression dari modul linear_model untuk membangun model regresi linear
from sklearn.linear_model import LinearRegression

# Mengimpor fungsi r2_score dari metrics untuk mengukur kinerja model
from sklearn.metrics import r2_score

# Mengimpor beberapa fungsi dari modul sklearn.metrics untuk menghitung confusion matrix dan classification report
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score

# %% [markdown]
# **Import Data Input**

# %%
# Membaca file CSV yang berisi data pembayaran mobil dan dimuat ke dalam DataFrame pandas df
df = pd.read_csv('/content/car_purchasing.csv', encoding='ISO-8859-1')

# Menampilkan lima baris pertama dari DataFrame
df.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# 2  638467.1773          42925.70921
# 3  548599.0524          67422.36313
# 4  560304.0671          55915.46248

# %% [markdown]
# **Preprocessing**

# %%
# Menghapus kolom-kolom yang tidak diperlukan di DataFrame
df.drop(columns=['customer name', 'customer e-mail', 'country', 'gender'], inplace=True)

# %% [markdown]
# **Menampilkan Data**

# %%
# Menampilkan lima baris pertama dari DataFrame setelah dilakukan penghapusan kolom
df.head()
# Out:
#          age  annual Salary  credit card debt    net worth  \
# 0  41.851720    62812.09301      11609.380910  238961.2505
# 1  40.870623    66646.89292       9572.957136  530973.9078
# 2  43.152897    53798.55112      11160.355060  638467.1773
# 3  58.271369    79370.03798      14426.164850  548599.0524
# 4  57.313749    59729.15130       5358.712177  560304.0671
#
#    car purchase amount
# 0          35321.45877
# 1          45115.52566
# 2          42925.70921
# 3          67422.36313
# 4          55915.46248

# %% [markdown]
# **Informasi Data**

# %%
# Memberikan ringkasan informasi tentang DataFrame
df.info()
# Menghitung jumlah nilai yang hilang di setiap kolom DataFrame
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  500 non-null    float64
#  1   annual Salary        500 non-null    float64
#  2   credit card debt     500 non-null    float64
#  3   net worth            500 non-null    float64
#  4   car purchase amount  500 non-null    float64
# dtypes: float64(5)
# memory usage: 19.7 KB
# age                    0
# annual Salary          0
# credit card debt       0
# net worth              0
# car purchase amount    0
# dtype: int64

# %% [markdown]
# **Visualisasi**

# %%
# Membuat visualisasi dengan menggunakan scatter plot dan pairplot untuk mengeksplorasi hubungan antara variabel-variabel di DataFrame
plt.scatter(df['annual Salary'], df['credit card debt'])
plt.xlabel('annual Salary')
plt.ylabel('credit card debt')
plt.title('The Corr Between Credit Card And Annual Salary')
# Out:
# Text(0.5, 1.0, 'The Corr Between Credit Card And Annual Salary')

# %% [markdown]
# **Plot Keseluruhan**

# %%
# Membuat matriks scatter plot dari pasangan variabel di DataFrame
sns.pairplot(df)

# %% [markdown]
# **Data Splitting**

# %%
# Memisahkan data menjadi fitur (X) dan target (y)
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %% [markdown]
# **Preprocessing**

# %%
# Menyesuaikan skala fitur menggunakan MinMaxScaler dan membagi data menjadi set pelatihan dan pengujian
scale = MinMaxScaler()
X = scale.fit_transform(X)
y = scale.fit_transform(y.values.reshape(-1, 1))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# **Regresi Linear**

# %%
# Membuat model regresi linear
lreg = LinearRegression()
# Melatih dengan data pelatihan
lreg.fit(X_train, y_train)
print('Train Score', lreg.score(X_train, y_train))
print('Test Score', lreg.score(X_test, y_test))
# Out:
# Train Score 0.9999999819904801
# Test Score 0.9999999782384801

# %% [markdown]
# **Prediksi Data**

# %%
# Menyimpan nilai yang diprediksi
y_pred = lreg.predict(X_test)

# %% [markdown]
# **ANN Model**

# %%
# Membuat model ANN
ann = Sequential([Dense(32, activation="relu"),
                  Dense(1, activation='linear')])

# Di-compile dengan optimizer dan fungsi loss
ann.compile(optimizer='adam',
            loss='mean_squared_error',
            metrics=['mean_absolute_error'])

# Dilatih dengan data train
history = ann.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 22ms/step - loss: 0.0623 - mean_absolute_error: 0.2155 - val_loss: 0.0296 - val_mean_absolute_error: 0.1458
# Epoch 2/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0213 - mean_absolute_error: 0.1150 - val_loss: 0.0101 - val_mean_absolute_error: 0.0839
# Epoch 3/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0143 - mean_absolute_error: 0.0962 - val_loss: 0.0097 - val_mean_absolute_error: 0.0803
# Epoch 4/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0135 - mean_absolute_error: 0.0940 - val_loss: 0.0083 - val_mean_absolute_error: 0.0744
# Epoch 5/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0113 - mean_absolute_error: 0.0846 - val_loss: 0.0072 - val_mean_absolute_error: 0.0704
# Epoch 6/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0099 - mean_absolute_error: 0.0780 - val_loss: 0.0067 - val_mean_absolute_error: 0.0673
# Epoch 7/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0091 - mean_absolute_error: 0.0741 - val_loss: 0.0060 - val_mean_absolute_error: 0.0632
# Epoch 8/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0082 - mean_absolute_error: 0.0707 - val_loss: 0.0052 - val_mean_absolute_error: 0.0590
# Epoch 9/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0074 - mean_absolute_error: 0.0673 - val_loss: 0.0047 - val_mean_absolute_error: 0.0559
# Epoch 10/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0068 - mean_absolute_error: 0.0640 - val_loss: 0.0043 - val_mean_absolute_error: 0.0532
# Epoch 11/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0062 - mean_absolute_error: 0.0608 - val_loss: 0.0040 - val_mean_absolute_error: 0.0507
# Epoch 12/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0057 - mean_absolute_error: 0.0583 - val_loss: 0.0036 - val_mean_absolute_error: 0.0484
# Epoch 13/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0052 - mean_absolute_error: 0.0557 - val_loss: 0.0033 - val_mean_absolute_error: 0.0464
# Epoch 14/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0048 - mean_absolute_error: 0.0538 - val_loss: 0.0031 - val_mean_absolute_error: 0.0444
# Epoch 15/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0044 - mean_absolute_error: 0.0516 - val_loss: 0.0029 - val_mean_absolute_error: 0.0427
# Epoch 16/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0041 - mean_absolute_error: 0.0497 - val_loss: 0.0027 - val_mean_absolute_error: 0.0411
# Epoch 17/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0038 - mean_absolute_error: 0.0479 - val_loss: 0.0026 - val_mean_absolute_error: 0.0400
# Epoch 18/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0035 - mean_absolute_error: 0.0462 - val_loss: 0.0023 - val_mean_absolute_error: 0.0386
# Epoch 19/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0033 - mean_absolute_error: 0.0445 - val_loss: 0.0022 - val_mean_absolute_error: 0.0377
# Epoch 20/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0031 - mean_absolute_error: 0.0431 - val_loss: 0.0021 - val_mean_absolute_error: 0.0370
# Epoch 21/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0029 - mean_absolute_error: 0.0416 - val_loss: 0.0020 - val_mean_absolute_error: 0.0357
# Epoch 22/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0027 - mean_absolute_error: 0.0402 - val_loss: 0.0018 - val_mean_absolute_error: 0.0347
# Epoch 23/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0025 - mean_absolute_error: 0.0389 - val_loss: 0.0018 - val_mean_absolute_error: 0.0340
# Epoch 24/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0023 - mean_absolute_error: 0.0376 - val_loss: 0.0016 - val_mean_absolute_error: 0.0330
# Epoch 25/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0022 - mean_absolute_error: 0.0364 - val_loss: 0.0015 - val_mean_absolute_error: 0.0322
# Epoch 26/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0353 - val_loss: 0.0014 - val_mean_absolute_error: 0.0312
# Epoch 27/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0019 - mean_absolute_error: 0.0341 - val_loss: 0.0014 - val_mean_absolute_error: 0.0304
# Epoch 28/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0334 - val_loss: 0.0013 - val_mean_absolute_error: 0.0292
# Epoch 29/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0016 - mean_absolute_error: 0.0317 - val_loss: 0.0012 - val_mean_absolute_error: 0.0285
# Epoch 30/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0015 - mean_absolute_error: 0.0308 - val_loss: 0.0011 - val_mean_absolute_error: 0.0273
# Epoch 31/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0014 - mean_absolute_error: 0.0293 - val_loss: 0.0010 - val_mean_absolute_error: 0.0264
# Epoch 32/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0013 - mean_absolute_error: 0.0283 - val_loss: 9.4478e-04 - val_mean_absolute_error: 0.0253
# Epoch 33/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0271 - val_loss: 8.8670e-04 - val_mean_absolute_error: 0.0244
# Epoch 34/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0011 - mean_absolute_error: 0.0261 - val_loss: 8.1737e-04 - val_mean_absolute_error: 0.0234
# Epoch 35/50
# 10/10 [==============================] - 0s 7ms/step - loss: 9.8899e-04 - mean_absolute_error: 0.0250 - val_loss: 7.5821e-04 - val_mean_absolute_error: 0.0225
# Epoch 36/50
# 10/10 [==============================] - 0s 8ms/step - loss: 9.0973e-04 - mean_absolute_error: 0.0239 - val_loss: 6.8881e-04 - val_mean_absolute_error: 0.0214
# Epoch 37/50
# 10/10 [==============================] - 0s 6ms/step - loss: 8.4482e-04 - mean_absolute_error: 0.0229 - val_loss: 6.3868e-04 - val_mean_absolute_error: 0.0206
# Epoch 38/50
# 10/10 [==============================] - 0s 6ms/step - loss: 7.5295e-04 - mean_absolute_error: 0.0218 - val_loss: 5.7961e-04 - val_mean_absolute_error: 0.0197
# Epoch 39/50
# 10/10 [==============================] - 0s 5ms/step - loss: 6.8247e-04 - mean_absolute_error: 0.0206 - val_loss: 5.5584e-04 - val_mean_absolute_error: 0.0191
# Epoch 40/50
# 10/10 [==============================] - 0s 5ms/step - loss: 6.3014e-04 - mean_absolute_error: 0.0197 - val_loss: 4.9289e-04 - val_mean_absolute_error: 0.0182
# Epoch 41/50
# 10/10 [==============================] - 0s 7ms/step - loss: 5.6780e-04 - mean_absolute_error: 0.0187 - val_loss: 4.5722e-04 - val_mean_absolute_error: 0.0174
# Epoch 42/50
# 10/10 [==============================] - 0s 6ms/step - loss: 5.2153e-04 - mean_absolute_error: 0.0178 - val_loss: 4.1505e-04 - val_mean_absolute_error: 0.0167
# Epoch 43/50
# 10/10 [==============================] - 0s 7ms/step - loss: 4.7519e-04 - mean_absolute_error: 0.0170 - val_loss: 3.8664e-04 - val_mean_absolute_error: 0.0159
# Epoch 44/50
# 10/10 [==============================] - 0s 7ms/step - loss: 4.3638e-04 - mean_absolute_error: 0.0163 - val_loss: 3.4873e-04 - val_mean_absolute_error: 0.0153
# Epoch 45/50
# 10/10 [==============================] - 0s 7ms/step - loss: 4.0482e-04 - mean_absolute_error: 0.0155 - val_loss: 3.2135e-04 - val_mean_absolute_error: 0.0146
# Epoch 46/50
# 10/10 [==============================] - 0s 5ms/step - loss: 3.6647e-04 - mean_absolute_error: 0.0147 - val_loss: 2.9953e-04 - val_mean_absolute_error: 0.0139
# Epoch 47/50
# 10/10 [==============================] - 0s 7ms/step - loss: 3.3821e-04 - mean_absolute_error: 0.0139 - val_loss: 2.7104e-04 - val_mean_absolute_error: 0.0133
# Epoch 48/50
# 10/10 [==============================] - 0s 5ms/step - loss: 3.1494e-04 - mean_absolute_error: 0.0136 - val_loss: 2.5599e-04 - val_mean_absolute_error: 0.0127
# Epoch 49/50
# 10/10 [==============================] - 0s 6ms/step - loss: 2.8471e-04 - mean_absolute_error: 0.0125 - val_loss: 2.2953e-04 - val_mean_absolute_error: 0.0122
# Epoch 50/50
# 10/10 [==============================] - 0s 7ms/step - loss: 2.5291e-04 - mean_absolute_error: 0.0118 - val_loss: 2.1813e-04 - val_mean_absolute_error: 0.0115

# %% [markdown]
# **Grafik Training & Validation Loss/Accuracy**

# %%
# Akurasi dari model yang dilatih terhadap data training
tr_acc = history.history['mean_absolute_error']

# Kerugian yang dihasilkan selama proses pelatihan model pada data training
tr_loss = history.history['loss']

# Akurasi model yang dinilai terhadap data validasi
val_acc = history.history['val_mean_absolute_error']

# Kerugian pada data validasi selama proses pelatihan model
val_loss = history.history['val_loss']

index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmin(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training Loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation Loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1, acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %% [markdown]
# **Prediksi ANN**

# %%
# Menyimpan prediksi yang dihasilkan oleh model ANN
ann_y_pred = ann.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %% [markdown]
# **Skor R2**

# %%
# Mencetak skor R2 untuk model ANN pada set pelatihan dan pengujian
r2 = r2_score(y_test, y_pred)
print('R2 Score:', r2)
# Out:
# R2 Score: 0.9999999782384801

# %% [markdown]
# **Evaluasi ANN**

# %%
ann.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6583e-04 - mean_absolute_error: 0.0104
# [0.0002658296434674412, 0.010435856878757477]

# %% [markdown]
# **Prediksi ANN**

# %%
# Mengevaluasi kinerja model ANN
ann.predict([[40, 70000.500, 9550,534000]])
# Out:
# 1/1 [==============================] - 0s 38ms/step
# array([[186864.8]], dtype=float32)

# %% [markdown]
# **Plotting Prediksi vs Hasil**

# %%
# Membuat plot yang membandingkan nilai aktual dengan nilai yang diprediksi oleh model regresi linear dan model ANN
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, label='Linear Regression')
plt.scatter(y_test, ann_y_pred, label='ANN')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='gray')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Predicted vs Actual Values')
plt.legend()
plt.show()

# %% [markdown]
# **Prediksi Hasil Tes Set**

# %%
# Memprediksi hasil tes set
y_pred = lreg.predict(X_test)
y_pred = (y_pred > 0.5)

# Untuk mengatur representasi teks dari baris np saat dicetak ke layar
np.set_printoptions()

# %% [markdown]
# **Convert ke Biner**

# %%
# Ubah y_test dan y_pred ke biner agar dapat dibuat confusion matrix-nya
y_test_binary = (y_test >= 0.5).astype(int)
y_pred_binary = (y_pred >= 0.5).astype(int)

# %% [markdown]
# **Confusion Matrix**

# %%
# Tentukan skema warna untuk visualisasi data
cmap1 = sns.diverging_palette(275,150,  s=40, l=65, n=6)
plt.subplots(figsize=(12,8))

# Membuat Confusion Matrix
cf_matrix = confusion_matrix(y_test_binary, y_pred_binary)

# Gunakan heatmap untuk mem-visualisasi matriks data dalam bentuk matriks warna
sns.heatmap(cf_matrix/np.sum(cf_matrix), cmap = cmap1, annot = True, annot_kws = {'size':15})
# Out:
# <Axes: >

# %% [markdown]
# **Classification Report**

# %%
# Membuat classification report (gunakan set yang telah diubah ke biner)
print(classification_report(y_test_binary, y_pred_binary))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        53
#            1       1.00      1.00      1.00        47
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100
